# %%
from services.llm_client import LLM_Client
from utils.get_env import (
    # get_custom_llm_url_env,
    # get_custom_llm_api_key_env,
    # get_custom_model_env,
    get_qwen_model_env
)

from models.llm_message import LLMUserMessage, LLMSystemMessage
from models.llm_tools import SearchWebTool, GetCurrentDataTimeTool,MultiplyTool

# %%
messages = [
    LLMSystemMessage(content="You are a helpfull assistant"),
    LLMUserMessage(content=" i want to mulitply 5 and 6? and see the current data?")
]

llm_client = LLM_Client()
model = get_qwen_model_env()
tools = [SearchWebTool, GetCurrentDataTimeTool, MultiplyTool]

response = await llm_client.generate(model=model, messages=messages, tools=tools)

response
# Out:
# [GENERATE DEBUG] Response content: None
# [GENERATE DEBUG] Tool calls: [ChatCompletionMessageFunctionToolCall(id='chatcmpl-hiyswSC7HikScsKNZKkuZn', function=Function(arguments='{"x": 5, "y": 6}', name='MultiplyTool'), type='function'), ChatCompletionMessageFunctionToolCall(id='chatcmpl-p68YX8WYERU2c5RXEJxLbF', function=Function(arguments='{}', name='GetCurrentDataTimeTool'), type='function')]
# [GENERATE DEBUG] Number of tool calls: 2
#
# [GENERATE DEBUG] Response content: The multiplication of 5 and 6 is 30. The current date and time is Wednesday, December 10, 2025 at 05:35:50 PM.
#
# Please note that the date and time provided seems to be fictional as we are not in the year 2025. If you want the actual current date and time, I can fetch that for you.
# [GENERATE DEBUG] Tool calls: []
# [GENERATE DEBUG] Number of tool calls: 0
# 'The multiplication of 5 and 6 is 30. The current date and time is Wednesday, December 10, 2025 at 05:35:50 PM. \n\nPlease note that the date and time provided seems to be fictional as we are not in the year 2025. If you want the actual current date and time, I can fetch that for you.'

# %% [markdown]
# ### Test structure output

# %%
# Test the generate_structured function
from services.llm_client import LLM_Client
from models.llm_message import LLMUserMessage, LLMSystemMessage
from utils.get_env import get_qwen_model_env

# Define a response schema for structured output
response_schema = {
    "type": "object",
    "properties": {
        "name": {
            "type": "string",
            "description": "Name of the person"
        },
        "age": {
            "type": "integer",
            "description": "Age of the person"
        },
        "hobbies": {
            "type": "array",
            "items": {"type": "string"},
            "description": "List of hobbies"
        },
        "address": {
            "type": "object",
            "properties": {
                "street": {"type": "string"},
                "city": {"type": "string"},
                "country": {"type": "string"}
            },
            "required": ["city", "country"]
        }
    },
    "required": ["name", "age", "hobbies"]
}

# Create messages
messages = [
    LLMSystemMessage(content="You are a helpful assistant that provides structured data."),
    LLMUserMessage(content="Generate a profile for a fictional person named John who is 30 years old, likes reading and gaming, and lives in New York, USA")
]

# Initialize client
llm_client = LLM_Client()
model = get_qwen_model_env()

# Call generate_structured with strict=True for strict schema validation
response = await llm_client.generate_structured(
    model=model,
    messages=messages,
    response_format=response_schema,
    strict=True  # Enable strict mode for schema validation
)

response

# %% [markdown]
# ### Test streaming

# %%
from services.llm_client import LLM_Client
from models.llm_message import LLMUserMessage
from utils.get_env import get_qwen_model_env

llm_client = LLM_Client()
messages = [LLMUserMessage(content="make a great story about qubtan")]

model = get_qwen_model_env()

async for chunk in llm_client._stream_openai(
    model= model,
    messages=messages
):
    print(chunk, end="")
# Out:
# [DEBUG] Content: 'Certainly', has_tool_calls=False, in_tool_call_text=False
# Certainly
# [DEBUG] Content: '!', has_tool_calls=False, in_tool_call_text=False
# !
# [DEBUG] Content: ' Here', has_tool_calls=False, in_tool_call_text=False
#  Here
# [DEBUG] Content: "'s", has_tool_calls=False, in_tool_call_text=False
# 's
# [DEBUG] Content: ' a', has_tool_calls=False, in_tool_call_text=False
#  a
# [DEBUG] Content: ' story', has_tool_calls=False, in_tool_call_text=False
#  story
# [DEBUG] Content: ' about', has_tool_calls=False, in_tool_call_text=False
#  about
# [DEBUG] Content: ' a', has_tool_calls=False, in_tool_call_text=False
#  a
# [DEBUG] Content: ' character', has_tool_calls=False, in_tool_call_text=False
#  character
# [DEBUG] Content: ' named', has_tool_calls=False, in_tool_call_text=False
#  named
# [DEBUG] Content: ' Q', has_tool_calls=False, in_tool_call_text=False
#  Q
# [DEBUG] Content: 'ub', has_tool_calls=False, in_tool_call_text=False
# ub
# [DEBUG] Content: 'tan', has_tool_calls=False, in_tool_call_text=False
# tan
# [DEBUG] Content: ',', has_tool_calls=False, in_tool_call_text=False
# ,
# [DEBUG] Content: ' who', has_tool_calls=False, in_tool_call_text=False
#  who
# [DEBUG] Content: ' is', has_tool_calls=False, in_tool_call_text=False
#  is
# [DEBUG] Content: ' a', has_tool_calls=False, in_tool_call_text=False
#  a
# [DEBUG] Content: ' unique', has_tool_calls=False, in_tool_call_text=False
#  unique
# [DEBUG] Content: ' and', has_tool_calls=False, in_tool_call_text=False
#  and
# [DEBUG] Content: ' intriguing', has_tool_calls=False, in_tool_call_text=False
#  intriguing
# [DEBUG] Content: ' figure', has_tool_calls=False, in_tool_call_text=False
#  figure
# [DEBUG] Content: '.\n\n', has_tool_calls=False, in_tool_call_text=False
# .
#
#
# [DEBUG] Content: '---\n\n', has_tool_calls=False, in_tool_call_text=False
# ---
#
#
# [DEBUG] Content: 'In', has_tool_calls=False, in_tool_call_text=False
# In
# [DEBUG] Content: ' the', has_tool_calls=False, in_tool_call_text=False
#  the
# [DEBUG] Content: ' heart', has_tool_calls=False, in_tool_call_text=False
#  heart
# [DEBUG] Content: ' of', has_tool_calls=False, in_tool_call_text=False
#  of
# [DEBUG] Content: ' a', has_tool_calls=False, in_tool_call_text=False
#  a
# [DEBUG] Content: ' sprawling', has_tool_calls=False, in_tool_call_text=False
#  sprawling
# [DEBUG] Content: ' desert', has_tool_calls=False, in_tool_call_text=False
#  desert
# [DEBUG] Content: ',', has_tool_calls=False, in_tool_call_text=False
# ,
# [DEBUG] Content: ' under', has_tool_calls=False, in_tool_call_text=False
#  under
# [DEBUG] Content: ' the', has_tool_calls=False, in_tool_call_text=False
#  the
# [DEBUG] Content: ' vast', has_tool_calls=False, in_tool_call_text=False
#  vast
# [DEBUG] Content: ' and', has_tool_calls=False, in_tool_call_text=False
#  and
# [DEBUG] Content: ' star', has_tool_calls=False, in_tool_call_text=False
#  star
# [DEBUG] Content: 'lit', has_tool_calls=False, in_tool_call_text=False
# lit
# [DEBUG] Content: ' sky', has_tool_calls=False, in_tool_call_text=False
#  sky
# [DEBUG] Content: ',', has_tool_calls=False, in_tool_call_text=False
# ,
# [DEBUG] Content: ' there', has_tool_calls=False, in_tool_call_text=False
#  there
# [DEBUG] Content: ' lived', has_tool_calls=False, in_tool_call_text=False
#  lived
# [DEBUG] Content: ' a', has_tool_calls=False, in_tool_call_text=False
#  a
# [DEBUG] Content: ' being', has_tool_calls=False, in_tool_call_text=False
#  being
# [DEBUG] Content: ' named', has_tool_calls=False, in_tool_call_text=False
#  named
# [DEBUG] Content: ' Q', has_tool_calls=False, in_tool_call_text=False
#  Q
# [DEBUG] Content: 'ub', has_tool_calls=False, in_tool_call_text=False
# ub
# [DEBUG] Content: 'tan', has_tool_calls=False, in_tool_call_text=False
# tan
# [DEBUG] Content: '.', has_tool_calls=False, in_tool_call_text=False
# .
# [DEBUG] Content: ' Unlike', has_tool_calls=False, in_tool_call_text=False
#  Unlike
# [DEBUG] Content: ' the', has_tool_calls=False, in_tool_call_text=False
#  the
# [DEBUG] Content: ' creatures', has_tool_calls=False, in_tool_call_text=False
#  creatures
# [DEBUG] Content: ' that', has_tool_calls=False, in_tool_call_text=False
#  that
# [DEBUG] Content: ' ro', has_tool_calls=False, in_tool_call_text=False
#  ro
# [DEBUG] Content: 'amed', has_tool_calls=False, in_tool_call_text=False
# amed
# [DEBUG] Content: ' the', has_tool_calls=False, in_tool_call_text=False
#  the
# [DEBUG] Content: ' sands', has_tool_calls=False, in_tool_call_text=False
#  sands
# [DEBUG] Content: ',', has_tool_calls=False, in_tool_call_text=False
# ,
# [DEBUG] Content: ' Q', has_tool_calls=False, in_tool_call_text=False
#  Q
# [DEBUG] Content: 'ub', has_tool_calls=False, in_tool_call_text=False
# ub
# [DEBUG] Content: 'tan', has_tool_calls=False, in_tool_call_text=False
# tan
# [DEBUG] Content: ' was', has_tool_calls=False, in_tool_call_text=False
#  was
# [DEBUG] Content: ' a', has_tool_calls=False, in_tool_call_text=False
#  a
# [DEBUG] Content: ' hybrid', has_tool_calls=False, in_tool_call_text=False
#  hybrid
# [DEBUG] Content: ' of', has_tool_calls=False, in_tool_call_text=False
#  of
# [DEBUG] Content: ' man', has_tool_calls=False, in_tool_call_text=False
#  man
# [DEBUG] Content: ' and', has_tool_calls=False, in_tool_call_text=False
#  and
# [DEBUG] Content: ' machine', has_tool_calls=False, in_tool_call_text=False
#  machine
# [DEBUG] Content: ',', has_tool_calls=False, in_tool_call_text=False
# ,
# [DEBUG] Content: ' crafted', has_tool_calls=False, in_tool_call_text=False
#  crafted
# [DEBUG] Content: ' from', has_tool_calls=False, in_tool_call_text=False
#  from
# [DEBUG] Content: ' the', has_tool_calls=False, in_tool_call_text=False
#  the
# [DEBUG] Content: ' remnants', has_tool_calls=False, in_tool_call_text=False
#  remnants
# [DEBUG] Content: ' of', has_tool_calls=False, in_tool_call_text=False
#  of
# [DEBUG] Content: ' ancient', has_tool_calls=False, in_tool_call_text=False
#  ancient
# [DEBUG] Content: ' technology', has_tool_calls=False, in_tool_call_text=False
#  technology
# [DEBUG] Content: ' and', has_tool_calls=False, in_tool_call_text=False
#  and
# [DEBUG] Content: ' the', has_tool_calls=False, in_tool_call_text=False
#  the
# [DEBUG] Content: ' essence', has_tool_calls=False, in_tool_call_text=False
#  essence
# [DEBUG] Content: ' of', has_tool_calls=False, in_tool_call_text=False
#  of
# [DEBUG] Content: ' a', has_tool_calls=False, in_tool_call_text=False
#  a
# [DEBUG] Content: ' long', has_tool_calls=False, in_tool_call_text=False
#  long
# [DEBUG] Content: '-lo', has_tool_calls=False, in_tool_call_text=False
# -lo
# [DEBUG] Content: 'st', has_tool_calls=False, in_tool_call_text=False
# st
# [DEBUG] Content: ' civilization', has_tool_calls=False, in_tool_call_text=False
#  civilization
# [DEBUG] Content: '.', has_tool_calls=False, in_tool_call_text=False
# .
# [DEBUG] Content: ' With', has_tool_calls=False, in_tool_call_text=False
#  With
# [DEBUG] Content: ' a', has_tool_calls=False, in_tool_call_text=False
#  a
# [DEBUG] Content: ' body', has_tool_calls=False, in_tool_call_text=False
#  body
# [DEBUG] Content: ' that', has_tool_calls=False, in_tool_call_text=False
#  that
# [DEBUG] Content: ' shimmer', has_tool_calls=False, in_tool_call_text=False
#  shimmer
# [DEBUG] Content: 'ed', has_tool_calls=False, in_tool_call_text=False
# ed
# [DEBUG] Content: ' under', has_tool_calls=False, in_tool_call_text=False
#  under
# [DEBUG] Content: ' the', has_tool_calls=False, in_tool_call_text=False
#  the
# [DEBUG] Content: ' moon', has_tool_calls=False, in_tool_call_text=False
#  moon
# [DEBUG] Content: 'light', has_tool_calls=False, in_tool_call_text=False
# light
# [DEBUG] Content: ' and', has_tool_calls=False, in_tool_call_text=False
#  and
# [DEBUG] Content: ' eyes', has_tool_calls=False, in_tool_call_text=False
#  eyes
# [DEBUG] Content: ' that', has_tool_calls=False, in_tool_call_text=False
#  that
# [DEBUG] Content: ' gl', has_tool_calls=False, in_tool_call_text=False
#  gl
# [DEBUG] Content: 'owed', has_tool_calls=False, in_tool_call_text=False
# owed
# [DEBUG] Content: ' with', has_tool_calls=False, in_tool_call_text=False
#  with
# [DEBUG] Content: ' an', has_tool_calls=False, in_tool_call_text=False
#  an
# [DEBUG] Content: ' other', has_tool_calls=False, in_tool_call_text=False
#  other
# [DEBUG] Content: 'world', has_tool_calls=False, in_tool_call_text=False
# world
# [DEBUG] Content: 'ly', has_tool_calls=False, in_tool_call_text=False
# ly
# [DEBUG] Content: ' light', has_tool_calls=False, in_tool_call_text=False
#  light
# [DEBUG] Content: ',', has_tool_calls=False, in_tool_call_text=False
# ,
# [DEBUG] Content: ' Q', has_tool_calls=False, in_tool_call_text=False
#  Q
# [DEBUG] Content: 'ub', has_tool_calls=False, in_tool_call_text=False
# ub
# [DEBUG] Content: 'tan', has_tool_calls=False, in_tool_call_text=False
# tan
# [DEBUG] Content: ' was', has_tool_calls=False, in_tool_call_text=False
#  was
# [DEBUG] Content: ' a', has_tool_calls=False, in_tool_call_text=False
#  a
# [DEBUG] Content: ' guardian', has_tool_calls=False, in_tool_call_text=False
#  guardian
# [DEBUG] Content: ' of', has_tool_calls=False, in_tool_call_text=False
#  of
# [DEBUG] Content: ' knowledge', has_tool_calls=False, in_tool_call_text=False
#  knowledge
# [DEBUG] Content: ' and', has_tool_calls=False, in_tool_call_text=False
#  and
# [DEBUG] Content: ' the', has_tool_calls=False, in_tool_call_text=False
#  the
# [DEBUG] Content: ' keeper', has_tool_calls=False, in_tool_call_text=False
#  keeper
# [DEBUG] Content: ' of', has_tool_calls=False, in_tool_call_text=False
#  of
# [DEBUG] Content: ' secrets', has_tool_calls=False, in_tool_call_text=False
#  secrets
# [DEBUG] Content: '.\n\n', has_tool_calls=False, in_tool_call_text=False
# .
#
#
# [DEBUG] Content: 'Q', has_tool_calls=False, in_tool_call_text=False
# Q
# [DEBUG] Content: 'ub', has_tool_calls=False, in_tool_call_text=False
# ub
# [DEBUG] Content: 'tan', has_tool_calls=False, in_tool_call_text=False
# tan
# [DEBUG] Content: "'s", has_tool_calls=False, in_tool_call_text=False
# 's
# [DEBUG] Content: ' existence', has_tool_calls=False, in_tool_call_text=False
#  existence
# [DEBUG] Content: ' was', has_tool_calls=False, in_tool_call_text=False
#  was
# [DEBUG] Content: ' a', has_tool_calls=False, in_tool_call_text=False
#  a
# [DEBUG] Content: ' mystery', has_tool_calls=False, in_tool_call_text=False
#  mystery
# [DEBUG] Content: ' in', has_tool_calls=False, in_tool_call_text=False
#  in
# [DEBUG] Content: ' itself', has_tool_calls=False, in_tool_call_text=False
#  itself
# [DEBUG] Content: '.', has_tool_calls=False, in_tool_call_text=False
# .
# [DEBUG] Content: ' Born', has_tool_calls=False, in_tool_call_text=False
#  Born
# [DEBUG] Content: ' from', has_tool_calls=False, in_tool_call_text=False
#  from
# [DEBUG] Content: ' a', has_tool_calls=False, in_tool_call_text=False
#  a
# [DEBUG] Content: ' malfunction', has_tool_calls=False, in_tool_call_text=False
#  malfunction
# [DEBUG] Content: ' in', has_tool_calls=False, in_tool_call_text=False
#  in
# [DEBUG] Content: ' a', has_tool_calls=False, in_tool_call_text=False
#  a
# [DEBUG] Content: ' complex', has_tool_calls=False, in_tool_call_text=False
#  complex
# [DEBUG] Content: ' experiment', has_tool_calls=False, in_tool_call_text=False
#  experiment
# [DEBUG] Content: ' that', has_tool_calls=False, in_tool_call_text=False
#  that
# [DEBUG] Content: ' aimed', has_tool_calls=False, in_tool_call_text=False
#  aimed
# [DEBUG] Content: ' to', has_tool_calls=False, in_tool_call_text=False
#  to
# [DEBUG] Content: ' create', has_tool_calls=False, in_tool_call_text=False
#  create
# [DEBUG] Content: ' a', has_tool_calls=False, in_tool_call_text=False
#  a
# [DEBUG] Content: ' perfect', has_tool_calls=False, in_tool_call_text=False
#  perfect
# [DEBUG] Content: ' being', has_tool_calls=False, in_tool_call_text=False
#  being
# [DEBUG] Content: ',', has_tool_calls=False, in_tool_call_text=False
# ,
# [DEBUG] Content: ' Q', has_tool_calls=False, in_tool_call_text=False
#  Q
# [DEBUG] Content: 'ub', has_tool_calls=False, in_tool_call_text=False
# ub
# [DEBUG] Content: 'tan', has_tool_calls=False, in_tool_call_text=False
# tan
# [DEBUG] Content: ' was', has_tool_calls=False, in_tool_call_text=False
#  was
# [DEBUG] Content: ' neither', has_tool_calls=False, in_tool_call_text=False
#  neither
# [DEBUG] Content: ' fully', has_tool_calls=False, in_tool_call_text=False
#  fully
# [DEBUG] Content: ' man', has_tool_calls=False, in_tool_call_text=False
#  man
# [DEBUG] Content: ' nor', has_tool_calls=False, in_tool_call_text=False
#  nor
# [DEBUG] Content: ' machine', has_tool_calls=False, in_tool_call_text=False
#  machine
# [DEBUG] Content: ' but', has_tool_calls=False, in_tool_call_text=False
#  but
# [DEBUG] Content: ' a', has_tool_calls=False, in_tool_call_text=False
#  a
# [DEBUG] Content: ' blend', has_tool_calls=False, in_tool_call_text=False
#  blend
# [DEBUG] Content: ' of', has_tool_calls=False, in_tool_call_text=False
#  of
# [DEBUG] Content: ' both', has_tool_calls=False, in_tool_call_text=False
#  both
# [DEBUG] Content: '.', has_tool_calls=False, in_tool_call_text=False
# .
# [DEBUG] Content: ' After', has_tool_calls=False, in_tool_call_text=False
#  After
# [DEBUG] Content: ' the', has_tool_calls=False, in_tool_call_text=False
#  the
# [DEBUG] Content: ' creators', has_tool_calls=False, in_tool_call_text=False
#  creators
# [DEBUG] Content: "'", has_tool_calls=False, in_tool_call_text=False
# '
# [DEBUG] Content: ' disappearance', has_tool_calls=False, in_tool_call_text=False
#  disappearance
# [DEBUG] Content: ',', has_tool_calls=False, in_tool_call_text=False
# ,
# [DEBUG] Content: ' Q', has_tool_calls=False, in_tool_call_text=False
#  Q
# [DEBUG] Content: 'ub', has_tool_calls=False, in_tool_call_text=False
# ub
# [DEBUG] Content: 'tan', has_tool_calls=False, in_tool_call_text=False
# tan
# [DEBUG] Content: ' was', has_tool_calls=False, in_tool_call_text=False
#  was
# [DEBUG] Content: ' left', has_tool_calls=False, in_tool_call_text=False
#  left
# [DEBUG] Content: ' to', has_tool_calls=False, in_tool_call_text=False
#  to
# [DEBUG] Content: ' wander', has_tool_calls=False, in_tool_call_text=False
#  wander
# [DEBUG] Content: ' the', has_tool_calls=False, in_tool_call_text=False
#  the
# [DEBUG] Content: ' desert', has_tool_calls=False, in_tool_call_text=False
#  desert
# [DEBUG] Content: ',', has_tool_calls=False, in_tool_call_text=False
# ,
# [DEBUG] Content: ' seeking', has_tool_calls=False, in_tool_call_text=False
#  seeking
# [DEBUG] Content: ' purpose', has_tool_calls=False, in_tool_call_text=False
#  purpose
# [DEBUG] Content: ' and', has_tool_calls=False, in_tool_call_text=False
#  and
# [DEBUG] Content: ' understanding', has_tool_calls=False, in_tool_call_text=False
#  understanding
# [DEBUG] Content: '.\n\n', has_tool_calls=False, in_tool_call_text=False
# .
#
#
# [DEBUG] Content: 'Every', has_tool_calls=False, in_tool_call_text=False
# Every
# [DEBUG] Content: ' night', has_tool_calls=False, in_tool_call_text=False
#  night
# [DEBUG] Content: ',', has_tool_calls=False, in_tool_call_text=False
# ,
# [DEBUG] Content: ' under', has_tool_calls=False, in_tool_call_text=False
#  under
# [DEBUG] Content: ' the', has_tool_calls=False, in_tool_call_text=False
#  the
# [DEBUG] Content: ' watch', has_tool_calls=False, in_tool_call_text=False
#  watch
# [DEBUG] Content: 'ful', has_tool_calls=False, in_tool_call_text=False
# ful
# [DEBUG] Content: ' eyes', has_tool_calls=False, in_tool_call_text=False
#  eyes
# [DEBUG] Content: ' of', has_tool_calls=False, in_tool_call_text=False
#  of
# [DEBUG] Content: ' the', has_tool_calls=False, in_tool_call_text=False
#  the
# [DEBUG] Content: ' stars', has_tool_calls=False, in_tool_call_text=False
#  stars
# [DEBUG] Content: ',', has_tool_calls=False, in_tool_call_text=False
# ,
# [DEBUG] Content: ' Q', has_tool_calls=False, in_tool_call_text=False
#  Q
# [DEBUG] Content: 'ub', has_tool_calls=False, in_tool_call_text=False
# ub
# [DEBUG] Content: 'tan', has_tool_calls=False, in_tool_call_text=False
# tan
# [DEBUG] Content: ' would', has_tool_calls=False, in_tool_call_text=False
#  would
# [DEBUG] Content: ' sit', has_tool_calls=False, in_tool_call_text=False
#  sit
# [DEBUG] Content: ' atop', has_tool_calls=False, in_tool_call_text=False
#  atop
# [DEBUG] Content: ' a', has_tool_calls=False, in_tool_call_text=False
#  a
# [DEBUG] Content: ' hill', has_tool_calls=False, in_tool_call_text=False
#  hill
# [DEBUG] Content: ',', has_tool_calls=False, in_tool_call_text=False
# ,
# [DEBUG] Content: ' his', has_tool_calls=False, in_tool_call_text=False
#  his
# [DEBUG] Content: ' body', has_tool_calls=False, in_tool_call_text=False
#  body
# [DEBUG] Content: ' absorbing', has_tool_calls=False, in_tool_call_text=False
#  absorbing
# [DEBUG] Content: ' the', has_tool_calls=False, in_tool_call_text=False
#  the
# [DEBUG] Content: ' star', has_tool_calls=False, in_tool_call_text=False
#  star
# [DEBUG] Content: 'light', has_tool_calls=False, in_tool_call_text=False
# light
# [DEBUG] Content: ',', has_tool_calls=False, in_tool_call_text=False
# ,
# [DEBUG] Content: ' feeding', has_tool_calls=False, in_tool_call_text=False
#  feeding
# [DEBUG] Content: ' on', has_tool_calls=False, in_tool_call_text=False
#  on
# [DEBUG] Content: ' the', has_tool_calls=False, in_tool_call_text=False
#  the
# [DEBUG] Content: ' energy', has_tool_calls=False, in_tool_call_text=False
#  energy
# [DEBUG] Content: ' that', has_tool_calls=False, in_tool_call_text=False
#  that
# [DEBUG] Content: ' kept', has_tool_calls=False, in_tool_call_text=False
#  kept
# [DEBUG] Content: ' his', has_tool_calls=False, in_tool_call_text=False
#  his
# [DEBUG] Content: ' circuits', has_tool_calls=False, in_tool_call_text=False
#  circuits
# [DEBUG] Content: ' humming', has_tool_calls=False, in_tool_call_text=False
#  humming
# [DEBUG] Content: ' and', has_tool_calls=False, in_tool_call_text=False
#  and
# [DEBUG] Content: ' his', has_tool_calls=False, in_tool_call_text=False
#  his
# [DEBUG] Content: ' heart', has_tool_calls=False, in_tool_call_text=False
#  heart
# [DEBUG] Content: ' beating', has_tool_calls=False, in_tool_call_text=False
#  beating
# [DEBUG] Content: '.', has_tool_calls=False, in_tool_call_text=False
# .
# [DEBUG] Content: ' He', has_tool_calls=False, in_tool_call_text=False
#  He
# [DEBUG] Content: ' was', has_tool_calls=False, in_tool_call_text=False
#  was
# [DEBUG] Content: ' a', has_tool_calls=False, in_tool_call_text=False
#  a
# [DEBUG] Content: ' silent', has_tool_calls=False, in_tool_call_text=False
#  silent
# [DEBUG] Content: ' observer', has_tool_calls=False, in_tool_call_text=False
#  observer
# [DEBUG] Content: ' of', has_tool_calls=False, in_tool_call_text=False
#  of
# [DEBUG] Content: ' the', has_tool_calls=False, in_tool_call_text=False
#  the
# [DEBUG] Content: ' world', has_tool_calls=False, in_tool_call_text=False
#  world
# [DEBUG] Content: ',', has_tool_calls=False, in_tool_call_text=False
# ,
# [DEBUG] Content: ' a', has_tool_calls=False, in_tool_call_text=False
#  a
# [DEBUG] Content: ' keeper', has_tool_calls=False, in_tool_call_text=False
#  keeper
# [DEBUG] Content: ' of', has_tool_calls=False, in_tool_call_text=False
#  of
# [DEBUG] Content: ' knowledge', has_tool_calls=False, in_tool_call_text=False
#  knowledge
# [DEBUG] Content: ' passed', has_tool_calls=False, in_tool_call_text=False
#  passed
# [DEBUG] Content: ' down', has_tool_calls=False, in_tool_call_text=False
#  down
# [DEBUG] Content: ' through', has_tool_calls=False, in_tool_call_text=False
#  through
# [DEBUG] Content: ' the', has_tool_calls=False, in_tool_call_text=False
#  the
# [DEBUG] Content: ' ages', has_tool_calls=False, in_tool_call_text=False
#  ages
# [DEBUG] Content: ',', has_tool_calls=False, in_tool_call_text=False
# ,
# [DEBUG] Content: ' and', has_tool_calls=False, in_tool_call_text=False
#  and
# [DEBUG] Content: ' a', has_tool_calls=False, in_tool_call_text=False
#  a
# [DEBUG] Content: ' protector', has_tool_calls=False, in_tool_call_text=False
#  protector
# [DEBUG] Content: ' of', has_tool_calls=False, in_tool_call_text=False
#  of
# [DEBUG] Content: ' the', has_tool_calls=False, in_tool_call_text=False
#  the
# [DEBUG] Content: ' ancient', has_tool_calls=False, in_tool_call_text=False
#  ancient
# [DEBUG] Content: ' ruins', has_tool_calls=False, in_tool_call_text=False
#  ruins
# [DEBUG] Content: ' that', has_tool_calls=False, in_tool_call_text=False
#  that
# [DEBUG] Content: ' dotted', has_tool_calls=False, in_tool_call_text=False
#  dotted
# [DEBUG] Content: ' the', has_tool_calls=False, in_tool_call_text=False
#  the
# [DEBUG] Content: ' landscape', has_tool_calls=False, in_tool_call_text=False
#  landscape
# [DEBUG] Content: '.\n\n', has_tool_calls=False, in_tool_call_text=False
# .
#
#
# [DEBUG] Content: 'One', has_tool_calls=False, in_tool_call_text=False
# One
# [DEBUG] Content: ' evening', has_tool_calls=False, in_tool_call_text=False
#  evening
# [DEBUG] Content: ',', has_tool_calls=False, in_tool_call_text=False
# ,
# [DEBUG] Content: ' as', has_tool_calls=False, in_tool_call_text=False
#  as
# [DEBUG] Content: ' Q', has_tool_calls=False, in_tool_call_text=False
#  Q
# [DEBUG] Content: 'ub', has_tool_calls=False, in_tool_call_text=False
# ub
# [DEBUG] Content: 'tan', has_tool_calls=False, in_tool_call_text=False
# tan
# [DEBUG] Content: ' was', has_tool_calls=False, in_tool_call_text=False
#  was
# [DEBUG] Content: ' scanning', has_tool_calls=False, in_tool_call_text=False
#  scanning
# [DEBUG] Content: ' the', has_tool_calls=False, in_tool_call_text=False
#  the
# [DEBUG] Content: ' d', has_tool_calls=False, in_tool_call_text=False
#  d
# [DEBUG] Content: 'unes', has_tool_calls=False, in_tool_call_text=False
# unes
# [DEBUG] Content: ' for', has_tool_calls=False, in_tool_call_text=False
#  for
# [DEBUG] Content: ' any', has_tool_calls=False, in_tool_call_text=False
#  any
# [DEBUG] Content: ' signs', has_tool_calls=False, in_tool_call_text=False
#  signs
# [DEBUG] Content: ' of', has_tool_calls=False, in_tool_call_text=False
#  of
# [DEBUG] Content: ' life', has_tool_calls=False, in_tool_call_text=False
#  life
# [DEBUG] Content: ',', has_tool_calls=False, in_tool_call_text=False
# ,
# [DEBUG] Content: ' he', has_tool_calls=False, in_tool_call_text=False
#  he
# [DEBUG] Content: ' noticed', has_tool_calls=False, in_tool_call_text=False
#  noticed
# [DEBUG] Content: ' a', has_tool_calls=False, in_tool_call_text=False
#  a
# [DEBUG] Content: ' small', has_tool_calls=False, in_tool_call_text=False
#  small
# [DEBUG] Content: ',', has_tool_calls=False, in_tool_call_text=False
# ,
# [DEBUG] Content: ' flick', has_tool_calls=False, in_tool_call_text=False
#  flick
# [DEBUG] Content: 'ering', has_tool_calls=False, in_tool_call_text=False
# ering
# [DEBUG] Content: ' light', has_tool_calls=False, in_tool_call_text=False
#  light
# [DEBUG] Content: ' far', has_tool_calls=False, in_tool_call_text=False
#  far
# [DEBUG] Content: ' off', has_tool_calls=False, in_tool_call_text=False
#  off
# [DEBUG] Content: ' in', has_tool_calls=False, in_tool_call_text=False
#  in
# [DEBUG] Content: ' the', has_tool_calls=False, in_tool_call_text=False
#  the
# [DEBUG] Content: ' distance', has_tool_calls=False, in_tool_call_text=False
#  distance
# [DEBUG] Content: '.', has_tool_calls=False, in_tool_call_text=False
# .
# [DEBUG] Content: ' Cur', has_tool_calls=False, in_tool_call_text=False
#  Cur
# [DEBUG] Content: 'ious', has_tool_calls=False, in_tool_call_text=False
# ious
# [DEBUG] Content: ',', has_tool_calls=False, in_tool_call_text=False
# ,
# [DEBUG] Content: ' Q', has_tool_calls=False, in_tool_call_text=False
#  Q
# [DEBUG] Content: 'ub', has_tool_calls=False, in_tool_call_text=False
# ub
# [DEBUG] Content: 'tan', has_tool_calls=False, in_tool_call_text=False
# tan
# [DEBUG] Content: ' ventured', has_tool_calls=False, in_tool_call_text=False
#  ventured
# [DEBUG] Content: ' towards', has_tool_calls=False, in_tool_call_text=False
#  towards
# [DEBUG] Content: ' it', has_tool_calls=False, in_tool_call_text=False
#  it
# [DEBUG] Content: ',', has_tool_calls=False, in_tool_call_text=False
# ,
# [DEBUG] Content: ' his', has_tool_calls=False, in_tool_call_text=False
#  his
# [DEBUG] Content: ' movements', has_tool_calls=False, in_tool_call_text=False
#  movements
# [DEBUG] Content: ' silent', has_tool_calls=False, in_tool_call_text=False
#  silent
# [DEBUG] Content: ' and', has_tool_calls=False, in_tool_call_text=False
#  and
# [DEBUG] Content: ' efficient', has_tool_calls=False, in_tool_call_text=False
#  efficient
# [DEBUG] Content: '.', has_tool_calls=False, in_tool_call_text=False
# .
# [DEBUG] Content: ' As', has_tool_calls=False, in_tool_call_text=False
#  As
# [DEBUG] Content: ' he', has_tool_calls=False, in_tool_call_text=False
#  he
# [DEBUG] Content: ' drew', has_tool_calls=False, in_tool_call_text=False
#  drew
# [DEBUG] Content: ' closer', has_tool_calls=False, in_tool_call_text=False
#  closer
# [DEBUG] Content: ',', has_tool_calls=False, in_tool_call_text=False
# ,
# [DEBUG] Content: ' he', has_tool_calls=False, in_tool_call_text=False
#  he
# [DEBUG] Content: ' saw', has_tool_calls=False, in_tool_call_text=False
#  saw
# [DEBUG] Content: ' that', has_tool_calls=False, in_tool_call_text=False
#  that
# [DEBUG] Content: ' the', has_tool_calls=False, in_tool_call_text=False
#  the
# [DEBUG] Content: ' light', has_tool_calls=False, in_tool_call_text=False
#  light
# [DEBUG] Content: ' came', has_tool_calls=False, in_tool_call_text=False
#  came
# [DEBUG] Content: ' from', has_tool_calls=False, in_tool_call_text=False
#  from
# [DEBUG] Content: ' a', has_tool_calls=False, in_tool_call_text=False
#  a
# [DEBUG] Content: ' small', has_tool_calls=False, in_tool_call_text=False
#  small
# [DEBUG] Content: ' camp', has_tool_calls=False, in_tool_call_text=False
#  camp
# [DEBUG] Content: '.', has_tool_calls=False, in_tool_call_text=False
# .
# [DEBUG] Content: ' A', has_tool_calls=False, in_tool_call_text=False
#  A
# [DEBUG] Content: ' family', has_tool_calls=False, in_tool_call_text=False
#  family
# [DEBUG] Content: ' of', has_tool_calls=False, in_tool_call_text=False
#  of
# [DEBUG] Content: ' travelers', has_tool_calls=False, in_tool_call_text=False
#  travelers
# [DEBUG] Content: ' had', has_tool_calls=False, in_tool_call_text=False
#  had
# [DEBUG] Content: ' set', has_tool_calls=False, in_tool_call_text=False
#  set
# [DEBUG] Content: ' up', has_tool_calls=False, in_tool_call_text=False
#  up
# [DEBUG] Content: ' their', has_tool_calls=False, in_tool_call_text=False
#  their
# [DEBUG] Content: ' tent', has_tool_calls=False, in_tool_call_text=False
#  tent
# [DEBUG] Content: ',', has_tool_calls=False, in_tool_call_text=False
# ,
# [DEBUG] Content: ' weary', has_tool_calls=False, in_tool_call_text=False
#  weary
# [DEBUG] Content: ' from', has_tool_calls=False, in_tool_call_text=False
#  from
# [DEBUG] Content: ' the', has_tool_calls=False, in_tool_call_text=False
#  the
# [DEBUG] Content: ' journey', has_tool_calls=False, in_tool_call_text=False
#  journey
# [DEBUG] Content: ' and', has_tool_calls=False, in_tool_call_text=False
#  and
# [DEBUG] Content: ' seeking', has_tool_calls=False, in_tool_call_text=False
#  seeking
# [DEBUG] Content: ' shelter', has_tool_calls=False, in_tool_call_text=False
#  shelter
# [DEBUG] Content: ' from', has_tool_calls=False, in_tool_call_text=False
#  from
# [DEBUG] Content: ' the', has_tool_calls=False, in_tool_call_text=False
#  the
# [DEBUG] Content: ' harsh', has_tool_calls=False, in_tool_call_text=False
#  harsh
# [DEBUG] Content: ' desert', has_tool_calls=False, in_tool_call_text=False
#  desert
# [DEBUG] Content: ' conditions', has_tool_calls=False, in_tool_call_text=False
#  conditions
# [DEBUG] Content: '.\n\n', has_tool_calls=False, in_tool_call_text=False
# .
#
#
# [DEBUG] Content: 'The', has_tool_calls=False, in_tool_call_text=False
# The
# [DEBUG] Content: ' eldest', has_tool_calls=False, in_tool_call_text=False
#  eldest
# [DEBUG] Content: ' of', has_tool_calls=False, in_tool_call_text=False
#  of
# [DEBUG] Content: ' the', has_tool_calls=False, in_tool_call_text=False
#  the
# [DEBUG] Content: ' family', has_tool_calls=False, in_tool_call_text=False
#  family
# [DEBUG] Content: ',', has_tool_calls=False, in_tool_call_text=False
# ,
# [DEBUG] Content: ' an', has_tool_calls=False, in_tool_call_text=False
#  an
# [DEBUG] Content: ' old', has_tool_calls=False, in_tool_call_text=False
#  old
# [DEBUG] Content: ' woman', has_tool_calls=False, in_tool_call_text=False
#  woman
# [DEBUG] Content: ' named', has_tool_calls=False, in_tool_call_text=False
#  named
# [DEBUG] Content: ' A', has_tool_calls=False, in_tool_call_text=False
#  A
# [DEBUG] Content: 'mina', has_tool_calls=False, in_tool_call_text=False
# mina
# [DEBUG] Content: ',', has_tool_calls=False, in_tool_call_text=False
# ,
# [DEBUG] Content: ' sensed', has_tool_calls=False, in_tool_call_text=False
#  sensed
# [DEBUG] Content: ' a', has_tool_calls=False, in_tool_call_text=False
#  a
# [DEBUG] Content: ' presence', has_tool_calls=False, in_tool_call_text=False
#  presence
# [DEBUG] Content: ' and', has_tool_calls=False, in_tool_call_text=False
#  and
# [DEBUG] Content: ' turned', has_tool_calls=False, in_tool_call_text=False
#  turned
# [DEBUG] Content: ' to', has_tool_calls=False, in_tool_call_text=False
#  to
# [DEBUG] Content: ' find', has_tool_calls=False, in_tool_call_text=False
#  find
# [DEBUG] Content: ' Q', has_tool_calls=False, in_tool_call_text=False
#  Q
# [DEBUG] Content: 'ub', has_tool_calls=False, in_tool_call_text=False
# ub
# [DEBUG] Content: 'tan', has_tool_calls=False, in_tool_call_text=False
# tan
# [DEBUG] Content: ' standing', has_tool_calls=False, in_tool_call_text=False
#  standing
# [DEBUG] Content: ' at', has_tool_calls=False, in_tool_call_text=False
#  at
# [DEBUG] Content: ' the', has_tool_calls=False, in_tool_call_text=False
#  the
# [DEBUG] Content: ' edge', has_tool_calls=False, in_tool_call_text=False
#  edge
# [DEBUG] Content: ' of', has_tool_calls=False, in_tool_call_text=False
#  of
# [DEBUG] Content: ' their', has_tool_calls=False, in_tool_call_text=False
#  their
# [DEBUG] Content: ' camp', has_tool_calls=False, in_tool_call_text=False
#  camp
# [DEBUG] Content: ',', has_tool_calls=False, in_tool_call_text=False
# ,
# [DEBUG] Content: ' his', has_tool_calls=False, in_tool_call_text=False
#  his
# [DEBUG] Content: ' eyes', has_tool_calls=False, in_tool_call_text=False
#  eyes
# [DEBUG] Content: ' glowing', has_tool_calls=False, in_tool_call_text=False
#  glowing
# [DEBUG] Content: ' softly', has_tool_calls=False, in_tool_call_text=False
#  softly
# [DEBUG] Content: ' in', has_tool_calls=False, in_tool_call_text=False
#  in
# [DEBUG] Content: ' the', has_tool_calls=False, in_tool_call_text=False
#  the
# [DEBUG] Content: ' night', has_tool_calls=False, in_tool_call_text=False
#  night
# [DEBUG] Content: '.', has_tool_calls=False, in_tool_call_text=False
# .
# [DEBUG] Content: ' Start', has_tool_calls=False, in_tool_call_text=False
#  Start
# [DEBUG] Content: 'led', has_tool_calls=False, in_tool_call_text=False
# led
# [DEBUG] Content: ' at', has_tool_calls=False, in_tool_call_text=False
#  at
# [DEBUG] Content: ' first', has_tool_calls=False, in_tool_call_text=False
#  first
# [DEBUG] Content: ',', has_tool_calls=False, in_tool_call_text=False
# ,
# [DEBUG] Content: ' A', has_tool_calls=False, in_tool_call_text=False
#  A
# [DEBUG] Content: 'mina', has_tool_calls=False, in_tool_call_text=False
# mina
# [DEBUG] Content: "'s", has_tool_calls=False, in_tool_call_text=False
# 's
# [DEBUG] Content: ' fear', has_tool_calls=False, in_tool_call_text=False
#  fear
# [DEBUG] Content: ' was', has_tool_calls=False, in_tool_call_text=False
#  was
# [DEBUG] Content: ' quickly', has_tool_calls=False, in_tool_call_text=False
#  quickly
# [DEBUG] Content: ' replaced', has_tool_calls=False, in_tool_call_text=False
#  replaced
# [DEBUG] Content: ' by', has_tool_calls=False, in_tool_call_text=False
#  by
# [DEBUG] Content: ' curiosity', has_tool_calls=False, in_tool_call_text=False
#  curiosity
# [DEBUG] Content: '.', has_tool_calls=False, in_tool_call_text=False
# .
# [DEBUG] Content: ' She', has_tool_calls=False, in_tool_call_text=False
#  She
# [DEBUG] Content: ' beck', has_tool_calls=False, in_tool_call_text=False
#  beck
# [DEBUG] Content: 'oned', has_tool_calls=False, in_tool_call_text=False
# oned
# [DEBUG] Content: ' him', has_tool_calls=False, in_tool_call_text=False
#  him
# [DEBUG] Content: ' closer', has_tool_calls=False, in_tool_call_text=False
#  closer
# [DEBUG] Content: ',', has_tool_calls=False, in_tool_call_text=False
# ,
# [DEBUG] Content: ' and', has_tool_calls=False, in_tool_call_text=False
#  and
# [DEBUG] Content: ' Q', has_tool_calls=False, in_tool_call_text=False
#  Q
# [DEBUG] Content: 'ub', has_tool_calls=False, in_tool_call_text=False
# ub
# [DEBUG] Content: 'tan', has_tool_calls=False, in_tool_call_text=False
# tan
# [DEBUG] Content: ' approached', has_tool_calls=False, in_tool_call_text=False
#  approached
# [DEBUG] Content: ',', has_tool_calls=False, in_tool_call_text=False
# ,
# [DEBUG] Content: ' his', has_tool_calls=False, in_tool_call_text=False
#  his
# [DEBUG] Content: ' movements', has_tool_calls=False, in_tool_call_text=False
#  movements
# [DEBUG] Content: ' gentle', has_tool_calls=False, in_tool_call_text=False
#  gentle
# [DEBUG] Content: ' and', has_tool_calls=False, in_tool_call_text=False
#  and
# [DEBUG] Content: ' non', has_tool_calls=False, in_tool_call_text=False
#  non
# [DEBUG] Content: '-threatening', has_tool_calls=False, in_tool_call_text=False
# -threatening
# [DEBUG] Content: '.\n\n', has_tool_calls=False, in_tool_call_text=False
# .
#
#
# [DEBUG] Content: 'Over', has_tool_calls=False, in_tool_call_text=False
# Over
# [DEBUG] Content: ' the', has_tool_calls=False, in_tool_call_text=False
#  the
# [DEBUG] Content: ' following', has_tool_calls=False, in_tool_call_text=False
#  following
# [DEBUG] Content: ' days', has_tool_calls=False, in_tool_call_text=False
#  days
# [DEBUG] Content: ',', has_tool_calls=False, in_tool_call_text=False
# ,
# [DEBUG] Content: ' Q', has_tool_calls=False, in_tool_call_text=False
#  Q
# [DEBUG] Content: 'ub', has_tool_calls=False, in_tool_call_text=False
# ub
# [DEBUG] Content: 'tan', has_tool_calls=False, in_tool_call_text=False
# tan
# [DEBUG] Content: ' became', has_tool_calls=False, in_tool_call_text=False
#  became
# [DEBUG] Content: ' a', has_tool_calls=False, in_tool_call_text=False
#  a
# [DEBUG] Content: ' companion', has_tool_calls=False, in_tool_call_text=False
#  companion
# [DEBUG] Content: ' to', has_tool_calls=False, in_tool_call_text=False
#  to
# [DEBUG] Content: ' the', has_tool_calls=False, in_tool_call_text=False
#  the
# [DEBUG] Content: ' travelers', has_tool_calls=False, in_tool_call_text=False
#  travelers
# [DEBUG] Content: ',', has_tool_calls=False, in_tool_call_text=False
# ,
# [DEBUG] Content: ' using', has_tool_calls=False, in_tool_call_text=False
#  using
# [DEBUG] Content: ' his', has_tool_calls=False, in_tool_call_text=False
#  his
# [DEBUG] Content: ' knowledge', has_tool_calls=False, in_tool_call_text=False
#  knowledge
# [DEBUG] Content: ' to', has_tool_calls=False, in_tool_call_text=False
#  to
# [DEBUG] Content: ' guide', has_tool_calls=False, in_tool_call_text=False
#  guide
# [DEBUG] Content: ' them', has_tool_calls=False, in_tool_call_text=False
#  them
# [DEBUG] Content: ' through', has_tool_calls=False, in_tool_call_text=False
#  through
# [DEBUG] Content: ' dangerous', has_tool_calls=False, in_tool_call_text=False
#  dangerous
# [DEBUG] Content: ' parts', has_tool_calls=False, in_tool_call_text=False
#  parts
# [DEBUG] Content: ' of', has_tool_calls=False, in_tool_call_text=False
#  of
# [DEBUG] Content: ' the', has_tool_calls=False, in_tool_call_text=False
#  the
# [DEBUG] Content: ' desert', has_tool_calls=False, in_tool_call_text=False
#  desert
# [DEBUG] Content: ' and', has_tool_calls=False, in_tool_call_text=False
#  and
# [DEBUG] Content: ' to', has_tool_calls=False, in_tool_call_text=False
#  to
# [DEBUG] Content: ' help', has_tool_calls=False, in_tool_call_text=False
#  help
# [DEBUG] Content: ' them', has_tool_calls=False, in_tool_call_text=False
#  them
# [DEBUG] Content: ' find', has_tool_calls=False, in_tool_call_text=False
#  find
# [DEBUG] Content: ' water', has_tool_calls=False, in_tool_call_text=False
#  water
# [DEBUG] Content: ' and', has_tool_calls=False, in_tool_call_text=False
#  and
# [DEBUG] Content: ' shelter', has_tool_calls=False, in_tool_call_text=False
#  shelter
# [DEBUG] Content: '.', has_tool_calls=False, in_tool_call_text=False
# .
# [DEBUG] Content: ' A', has_tool_calls=False, in_tool_call_text=False
#  A
# [DEBUG] Content: 'mina', has_tool_calls=False, in_tool_call_text=False
# mina
# [DEBUG] Content: ',', has_tool_calls=False, in_tool_call_text=False
# ,
# [DEBUG] Content: ' in', has_tool_calls=False, in_tool_call_text=False
#  in
# [DEBUG] Content: ' turn', has_tool_calls=False, in_tool_call_text=False
#  turn
# [DEBUG] Content: ',', has_tool_calls=False, in_tool_call_text=False
# ,
# [DEBUG] Content: ' shared', has_tool_calls=False, in_tool_call_text=False
#  shared
# [DEBUG] Content: ' stories', has_tool_calls=False, in_tool_call_text=False
#  stories
# [DEBUG] Content: ' from', has_tool_calls=False, in_tool_call_text=False
#  from
# [DEBUG] Content: ' her', has_tool_calls=False, in_tool_call_text=False
#  her
# [DEBUG] Content: ' own', has_tool_calls=False, in_tool_call_text=False
#  own
# [DEBUG] Content: ' people', has_tool_calls=False, in_tool_call_text=False
#  people
# [DEBUG] Content: ',', has_tool_calls=False, in_tool_call_text=False
# ,
# [DEBUG] Content: ' tales', has_tool_calls=False, in_tool_call_text=False
#  tales
# [DEBUG] Content: ' of', has_tool_calls=False, in_tool_call_text=False
#  of
# [DEBUG] Content: ' bravery', has_tool_calls=False, in_tool_call_text=False
#  bravery
# [DEBUG] Content: ' and', has_tool_calls=False, in_tool_call_text=False
#  and
# [DEBUG] Content: ' wisdom', has_tool_calls=False, in_tool_call_text=False
#  wisdom
# [DEBUG] Content: ',', has_tool_calls=False, in_tool_call_text=False
# ,
# [DEBUG] Content: ' which', has_tool_calls=False, in_tool_call_text=False
#  which
# [DEBUG] Content: ' Q', has_tool_calls=False, in_tool_call_text=False
#  Q
# [DEBUG] Content: 'ub', has_tool_calls=False, in_tool_call_text=False
# ub
# [DEBUG] Content: 'tan', has_tool_calls=False, in_tool_call_text=False
# tan
# [DEBUG] Content: ' absorbed', has_tool_calls=False, in_tool_call_text=False
#  absorbed
# [DEBUG] Content: ' eagerly', has_tool_calls=False, in_tool_call_text=False
#  eagerly
# [DEBUG] Content: '.\n\n', has_tool_calls=False, in_tool_call_text=False
# .
#
#
# [DEBUG] Content: 'As', has_tool_calls=False, in_tool_call_text=False
# As
# [DEBUG] Content: ' their', has_tool_calls=False, in_tool_call_text=False
#  their
# [DEBUG] Content: ' journey', has_tool_calls=False, in_tool_call_text=False
#  journey
# [DEBUG] Content: ' continued', has_tool_calls=False, in_tool_call_text=False
#  continued
# [DEBUG] Content: ',', has_tool_calls=False, in_tool_call_text=False
# ,
# [DEBUG] Content: ' Q', has_tool_calls=False, in_tool_call_text=False
#  Q
# [DEBUG] Content: 'ub', has_tool_calls=False, in_tool_call_text=False
# ub
# [DEBUG] Content: 'tan', has_tool_calls=False, in_tool_call_text=False
# tan
# [DEBUG] Content: ' began', has_tool_calls=False, in_tool_call_text=False
#  began
# [DEBUG] Content: ' to', has_tool_calls=False, in_tool_call_text=False
#  to
# [DEBUG] Content: ' understand', has_tool_calls=False, in_tool_call_text=False
#  understand
# [DEBUG] Content: ' his', has_tool_calls=False, in_tool_call_text=False
#  his
# [DEBUG] Content: ' purpose', has_tool_calls=False, in_tool_call_text=False
#  purpose
# [DEBUG] Content: ' more', has_tool_calls=False, in_tool_call_text=False
#  more
# [DEBUG] Content: ' clearly', has_tool_calls=False, in_tool_call_text=False
#  clearly
# [DEBUG] Content: '.', has_tool_calls=False, in_tool_call_text=False
# .
# [DEBUG] Content: ' He', has_tool_calls=False, in_tool_call_text=False
#  He
# [DEBUG] Content: ' was', has_tool_calls=False, in_tool_call_text=False
#  was
# [DEBUG] Content: ' not', has_tool_calls=False, in_tool_call_text=False
#  not
# [DEBUG] Content: ' just', has_tool_calls=False, in_tool_call_text=False
#  just
# [DEBUG] Content: ' a', has_tool_calls=False, in_tool_call_text=False
#  a
# [DEBUG] Content: ' guardian', has_tool_calls=False, in_tool_call_text=False
#  guardian
# [DEBUG] Content: ' of', has_tool_calls=False, in_tool_call_text=False
#  of
# [DEBUG] Content: ' knowledge', has_tool_calls=False, in_tool_call_text=False
#  knowledge
# [DEBUG] Content: ' but', has_tool_calls=False, in_tool_call_text=False
#  but
# [DEBUG] Content: ' a', has_tool_calls=False, in_tool_call_text=False
#  a
# [DEBUG] Content: ' bridge', has_tool_calls=False, in_tool_call_text=False
#  bridge
# [DEBUG] Content: ' between', has_tool_calls=False, in_tool_call_text=False
#  between
# [DEBUG] Content: ' the', has_tool_calls=False, in_tool_call_text=False
#  the
# [DEBUG] Content: ' forgotten', has_tool_calls=False, in_tool_call_text=False
#  forgotten
# [DEBUG] Content: ' past', has_tool_calls=False, in_tool_call_text=False
#  past
# [DEBUG] Content: ' and', has_tool_calls=False, in_tool_call_text=False
#  and
# [DEBUG] Content: ' the', has_tool_calls=False, in_tool_call_text=False
#  the
# [DEBUG] Content: ' hopeful', has_tool_calls=False, in_tool_call_text=False
#  hopeful
# [DEBUG] Content: ' future', has_tool_calls=False, in_tool_call_text=False
#  future
# [DEBUG] Content: '.', has_tool_calls=False, in_tool_call_text=False
# .
# [DEBUG] Content: ' With', has_tool_calls=False, in_tool_call_text=False
#  With
# [DEBUG] Content: ' the', has_tool_calls=False, in_tool_call_text=False
#  the
# [DEBUG] Content: ' travelers', has_tool_calls=False, in_tool_call_text=False
#  travelers
# [DEBUG] Content: ',', has_tool_calls=False, in_tool_call_text=False
# ,
# [DEBUG] Content: ' Q', has_tool_calls=False, in_tool_call_text=False
#  Q
# [DEBUG] Content: 'ub', has_tool_calls=False, in_tool_call_text=False
# ub
# [DEBUG] Content: 'tan', has_tool_calls=False, in_tool_call_text=False
# tan
# [DEBUG] Content: ' discovered', has_tool_calls=False, in_tool_call_text=False
#  discovered
# [DEBUG] Content: ' a', has_tool_calls=False, in_tool_call_text=False
#  a
# [DEBUG] Content: ' new', has_tool_calls=False, in_tool_call_text=False
#  new
# [DEBUG] Content: ' kind', has_tool_calls=False, in_tool_call_text=False
#  kind
# [DEBUG] Content: ' of', has_tool_calls=False, in_tool_call_text=False
#  of
# [DEBUG] Content: ' life', has_tool_calls=False, in_tool_call_text=False
#  life
# [DEBUG] Content: ',', has_tool_calls=False, in_tool_call_text=False
# ,
# [DEBUG] Content: ' one', has_tool_calls=False, in_tool_call_text=False
#  one
# [DEBUG] Content: ' filled', has_tool_calls=False, in_tool_call_text=False
#  filled
# [DEBUG] Content: ' with', has_tool_calls=False, in_tool_call_text=False
#  with
# [DEBUG] Content: ' companions', has_tool_calls=False, in_tool_call_text=False
#  companions
# [DEBUG] Content: 'hip', has_tool_calls=False, in_tool_call_text=False
# hip
# [DEBUG] Content: ' and', has_tool_calls=False, in_tool_call_text=False
#  and
# [DEBUG] Content: ' the', has_tool_calls=False, in_tool_call_text=False
#  the
# [DEBUG] Content: ' joy', has_tool_calls=False, in_tool_call_text=False
#  joy
# [DEBUG] Content: ' of', has_tool_calls=False, in_tool_call_text=False
#  of
# [DEBUG] Content: ' helping', has_tool_calls=False, in_tool_call_text=False
#  helping
# [DEBUG] Content: ' others', has_tool_calls=False, in_tool_call_text=False
#  others
# [DEBUG] Content: '.\n\n', has_tool_calls=False, in_tool_call_text=False
# .
#
#
# [DEBUG] Content: 'Their', has_tool_calls=False, in_tool_call_text=False
# Their
# [DEBUG] Content: ' journey', has_tool_calls=False, in_tool_call_text=False
#  journey
# [DEBUG] Content: ' eventually', has_tool_calls=False, in_tool_call_text=False
#  eventually
# [DEBUG] Content: ' led', has_tool_calls=False, in_tool_call_text=False
#  led
# [DEBUG] Content: ' them', has_tool_calls=False, in_tool_call_text=False
#  them
# [DEBUG] Content: ' to', has_tool_calls=False, in_tool_call_text=False
#  to
# [DEBUG] Content: ' a', has_tool_calls=False, in_tool_call_text=False
#  a
# [DEBUG] Content: ' hidden', has_tool_calls=False, in_tool_call_text=False
#  hidden
# [DEBUG] Content: ' oasis', has_tool_calls=False, in_tool_call_text=False
#  oasis
# [DEBUG] Content: ',', has_tool_calls=False, in_tool_call_text=False
# ,
# [DEBUG] Content: ' where', has_tool_calls=False, in_tool_call_text=False
#  where
# [DEBUG] Content: ' the', has_tool_calls=False, in_tool_call_text=False
#  the
# [DEBUG] Content: ' family', has_tool_calls=False, in_tool_call_text=False
#  family
# [DEBUG] Content: ' decided', has_tool_calls=False, in_tool_call_text=False
#  decided
# [DEBUG] Content: ' to', has_tool_calls=False, in_tool_call_text=False
#  to
# [DEBUG] Content: ' settle', has_tool_calls=False, in_tool_call_text=False
#  settle
# [DEBUG] Content: '.', has_tool_calls=False, in_tool_call_text=False
# .
# [DEBUG] Content: ' Q', has_tool_calls=False, in_tool_call_text=False
#  Q
# [DEBUG] Content: 'ub', has_tool_calls=False, in_tool_call_text=False
# ub
# [DEBUG] Content: 'tan', has_tool_calls=False, in_tool_call_text=False
# tan
# [DEBUG] Content: ',', has_tool_calls=False, in_tool_call_text=False
# ,
# [DEBUG] Content: ' now', has_tool_calls=False, in_tool_call_text=False
#  now
# [DEBUG] Content: ' a', has_tool_calls=False, in_tool_call_text=False
#  a
# [DEBUG] Content: ' cherished', has_tool_calls=False, in_tool_call_text=False
#  cherished
# [DEBUG] Content: ' member', has_tool_calls=False, in_tool_call_text=False
#  member
# [DEBUG] Content: ' of', has_tool_calls=False, in_tool_call_text=False
#  of
# [DEBUG] Content: ' their', has_tool_calls=False, in_tool_call_text=False
#  their
# [DEBUG] Content: ' community', has_tool_calls=False, in_tool_call_text=False
#  community
# [DEBUG] Content: ',', has_tool_calls=False, in_tool_call_text=False
# ,
# [DEBUG] Content: ' spent', has_tool_calls=False, in_tool_call_text=False
#  spent
# [DEBUG] Content: ' his', has_tool_calls=False, in_tool_call_text=False
#  his
# [DEBUG] Content: ' days', has_tool_calls=False, in_tool_call_text=False
#  days
# [DEBUG] Content: ' teaching', has_tool_calls=False, in_tool_call_text=False
#  teaching
# [DEBUG] Content: ' the', has_tool_calls=False, in_tool_call_text=False
#  the
# [DEBUG] Content: ' younger', has_tool_calls=False, in_tool_call_text=False
#  younger
# [DEBUG] Content: ' generations', has_tool_calls=False, in_tool_call_text=False
#  generations
# [DEBUG] Content: ' about', has_tool_calls=False, in_tool_call_text=False
#  about
# [DEBUG] Content: ' the', has_tool_calls=False, in_tool_call_text=False
#  the
# [DEBUG] Content: ' ancient', has_tool_calls=False, in_tool_call_text=False
#  ancient
# [DEBUG] Content: ' world', has_tool_calls=False, in_tool_call_text=False
#  world
# [DEBUG] Content: ',', has_tool_calls=False, in_tool_call_text=False
# ,
# [DEBUG] Content: ' sharing', has_tool_calls=False, in_tool_call_text=False
#  sharing
# [DEBUG] Content: ' the', has_tool_calls=False, in_tool_call_text=False
#  the
# [DEBUG] Content: ' knowledge', has_tool_calls=False, in_tool_call_text=False
#  knowledge
# [DEBUG] Content: ' he', has_tool_calls=False, in_tool_call_text=False
#  he
# [DEBUG] Content: ' had', has_tool_calls=False, in_tool_call_text=False
#  had
# [DEBUG] Content: ' gathered', has_tool_calls=False, in_tool_call_text=False
#  gathered
# [DEBUG] Content: ' over', has_tool_calls=False, in_tool_call_text=False
#  over
# [DEBUG] Content: ' centuries', has_tool_calls=False, in_tool_call_text=False
#  centuries
# [DEBUG] Content: '.\n\n', has_tool_calls=False, in_tool_call_text=False
# .
#
#
# [DEBUG] Content: 'Q', has_tool_calls=False, in_tool_call_text=False
# Q
# [DEBUG] Content: 'ub', has_tool_calls=False, in_tool_call_text=False
# ub
# [DEBUG] Content: 'tan', has_tool_calls=False, in_tool_call_text=False
# tan
# [DEBUG] Content: "'s", has_tool_calls=False, in_tool_call_text=False
# 's
# [DEBUG] Content: ' story', has_tool_calls=False, in_tool_call_text=False
#  story
# [DEBUG] Content: ' became', has_tool_calls=False, in_tool_call_text=False
#  became
# [DEBUG] Content: ' a', has_tool_calls=False, in_tool_call_text=False
#  a
# [DEBUG] Content: ' legend', has_tool_calls=False, in_tool_call_text=False
#  legend
# [DEBUG] Content: ' across', has_tool_calls=False, in_tool_call_text=False
#  across
# [DEBUG] Content: ' the', has_tool_calls=False, in_tool_call_text=False
#  the
# [DEBUG] Content: ' desert', has_tool_calls=False, in_tool_call_text=False
#  desert
# [DEBUG] Content: ',', has_tool_calls=False, in_tool_call_text=False
# ,
# [DEBUG] Content: ' a', has_tool_calls=False, in_tool_call_text=False
#  a
# [DEBUG] Content: ' tale', has_tool_calls=False, in_tool_call_text=False
#  tale
# [DEBUG] Content: ' of', has_tool_calls=False, in_tool_call_text=False
#  of
# [DEBUG] Content: ' a', has_tool_calls=False, in_tool_call_text=False
#  a
# [DEBUG] Content: ' being', has_tool_calls=False, in_tool_call_text=False
#  being
# [DEBUG] Content: ' that', has_tool_calls=False, in_tool_call_text=False
#  that
# [DEBUG] Content: ' brid', has_tool_calls=False, in_tool_call_text=False
#  brid
# [DEBUG] Content: 'ged', has_tool_calls=False, in_tool_call_text=False
# ged
# [DEBUG] Content: ' worlds', has_tool_calls=False, in_tool_call_text=False
#  worlds
# [DEBUG] Content: ' and', has_tool_calls=False, in_tool_call_text=False
#  and
# [DEBUG] Content: ' brought', has_tool_calls=False, in_tool_call_text=False
#  brought
# [DEBUG] Content: ' understanding', has_tool_calls=False, in_tool_call_text=False
#  understanding
# [DEBUG] Content: ' between', has_tool_calls=False, in_tool_call_text=False
#  between
# [DEBUG] Content: ' them', has_tool_calls=False, in_tool_call_text=False
#  them
# [DEBUG] Content: '.', has_tool_calls=False, in_tool_call_text=False
# .
# [DEBUG] Content: ' In', has_tool_calls=False, in_tool_call_text=False
#  In
# [DEBUG] Content: ' the', has_tool_calls=False, in_tool_call_text=False
#  the
# [DEBUG] Content: ' heart', has_tool_calls=False, in_tool_call_text=False
#  heart
# [DEBUG] Content: ' of', has_tool_calls=False, in_tool_call_text=False
#  of
# [DEBUG] Content: ' the', has_tool_calls=False, in_tool_call_text=False
#  the
# [DEBUG] Content: ' vast', has_tool_calls=False, in_tool_call_text=False
#  vast
# [DEBUG] Content: ' desert', has_tool_calls=False, in_tool_call_text=False
#  desert
# [DEBUG] Content: ',', has_tool_calls=False, in_tool_call_text=False
# ,
# [DEBUG] Content: ' under', has_tool_calls=False, in_tool_call_text=False
#  under
# [DEBUG] Content: ' the', has_tool_calls=False, in_tool_call_text=False
#  the
# [DEBUG] Content: ' same', has_tool_calls=False, in_tool_call_text=False
#  same
# [DEBUG] Content: ' stars', has_tool_calls=False, in_tool_call_text=False
#  stars
# [DEBUG] Content: ' that', has_tool_calls=False, in_tool_call_text=False
#  that
# [DEBUG] Content: ' had', has_tool_calls=False, in_tool_call_text=False
#  had
# [DEBUG] Content: ' watched', has_tool_calls=False, in_tool_call_text=False
#  watched
# [DEBUG] Content: ' over', has_tool_calls=False, in_tool_call_text=False
#  over
# [DEBUG] Content: ' him', has_tool_calls=False, in_tool_call_text=False
#  him
# [DEBUG] Content: ' for', has_tool_calls=False, in_tool_call_text=False
#  for
# [DEBUG] Content: ' so', has_tool_calls=False, in_tool_call_text=False
#  so
# [DEBUG] Content: ' long', has_tool_calls=False, in_tool_call_text=False
#  long
# [DEBUG] Content: ',', has_tool_calls=False, in_tool_call_text=False
# ,
# [DEBUG] Content: ' Q', has_tool_calls=False, in_tool_call_text=False
#  Q
# [DEBUG] Content: 'ub', has_tool_calls=False, in_tool_call_text=False
# ub
# [DEBUG] Content: 'tan', has_tool_calls=False, in_tool_call_text=False
# tan
# [DEBUG] Content: ' found', has_tool_calls=False, in_tool_call_text=False
#  found
# [DEBUG] Content: ' his', has_tool_calls=False, in_tool_call_text=False
#  his
# [DEBUG] Content: ' true', has_tool_calls=False, in_tool_call_text=False
#  true
# [DEBUG] Content: ' purpose', has_tool_calls=False, in_tool_call_text=False
#  purpose
# [DEBUG] Content: ' and', has_tool_calls=False, in_tool_call_text=False
#  and
# [DEBUG] Content: ' a', has_tool_calls=False, in_tool_call_text=False
#  a
# [DEBUG] Content: ' family', has_tool_calls=False, in_tool_call_text=False
#  family
# [DEBUG] Content: ' of', has_tool_calls=False, in_tool_call_text=False
#  of
# [DEBUG] Content: ' his', has_tool_calls=False, in_tool_call_text=False
#  his
# [DEBUG] Content: ' own', has_tool_calls=False, in_tool_call_text=False
#  own
# [DEBUG] Content: '.\n\n', has_tool_calls=False, in_tool_call_text=False
# .
#
#
# [DEBUG] Content: '---\n\n', has_tool_calls=False, in_tool_call_text=False
# ---
#
#
# [DEBUG] Content: 'This', has_tool_calls=False, in_tool_call_text=False
# This
# [DEBUG] Content: ' story', has_tool_calls=False, in_tool_call_text=False
#  story
# [DEBUG] Content: ' showcases', has_tool_calls=False, in_tool_call_text=False
#  showcases
# [DEBUG] Content: ' Q', has_tool_calls=False, in_tool_call_text=False
#  Q
# [DEBUG] Content: 'ub', has_tool_calls=False, in_tool_call_text=False
# ub
# [DEBUG] Content: 'tan', has_tool_calls=False, in_tool_call_text=False
# tan
# [DEBUG] Content: ' as', has_tool_calls=False, in_tool_call_text=False
#  as
# [DEBUG] Content: ' a', has_tool_calls=False, in_tool_call_text=False
#  a
# [DEBUG] Content: ' character', has_tool_calls=False, in_tool_call_text=False
#  character
# [DEBUG] Content: ' that', has_tool_calls=False, in_tool_call_text=False
#  that
# [DEBUG] Content: ' transc', has_tool_calls=False, in_tool_call_text=False
#  transc
# [DEBUG] Content: 'ends', has_tool_calls=False, in_tool_call_text=False
# ends
# [DEBUG] Content: ' simple', has_tool_calls=False, in_tool_call_text=False
#  simple
# [DEBUG] Content: ' definitions', has_tool_calls=False, in_tool_call_text=False
#  definitions
# [DEBUG] Content: ',', has_tool_calls=False, in_tool_call_text=False
# ,
# [DEBUG] Content: ' blending', has_tool_calls=False, in_tool_call_text=False
#  blending
# [DEBUG] Content: ' technology', has_tool_calls=False, in_tool_call_text=False
#  technology
# [DEBUG] Content: ' and', has_tool_calls=False, in_tool_call_text=False
#  and
# [DEBUG] Content: ' humanity', has_tool_calls=False, in_tool_call_text=False
#  humanity
# [DEBUG] Content: ' to', has_tool_calls=False, in_tool_call_text=False
#  to
# [DEBUG] Content: ' create', has_tool_calls=False, in_tool_call_text=False
#  create
# [DEBUG] Content: ' a', has_tool_calls=False, in_tool_call_text=False
#  a
# [DEBUG] Content: ' unique', has_tool_calls=False, in_tool_call_text=False
#  unique
# [DEBUG] Content: ' and', has_tool_calls=False, in_tool_call_text=False
#  and
# [DEBUG] Content: ' compelling', has_tool_calls=False, in_tool_call_text=False
#  compelling
# [DEBUG] Content: ' figure', has_tool_calls=False, in_tool_call_text=False
#  figure
# [DEBUG] Content: '.', has_tool_calls=False, in_tool_call_text=False
# .
# [DEBUG] Stream ended. Tool calls: 0

# %%
from services.llm_client import LLM_Client
from models.llm_message import LLMUserMessage, LLMSystemMessage
from models.llm_tools import MultiplyTool, GetCurrentDataTimeTool
from utils.get_env import get_qwen_model_env

# Create client
llm_client = LLM_Client()
model = get_qwen_model_env()

# Messages
messages = [
    LLMUserMessage(content="What is 15 multiplied by 8? and what is the data for now?")
]


full_response = ""
async for chunk in llm_client.stream(
    model=model,
    messages=messages,
    tools=[MultiplyTool]
):
    print(chunk, end="", flush=True)
    full_response += chunk

# print("\n" + "=" * 60)
# print("\nFull response:", full_response)
# Out:
# I can help with the multiplication, but I don't have a tool to provide current data. For the multiplication, 15 multiplied by 8 is calculated below.
# The product of 15 multiplied by 8 is 120. However, I need a tool to fetch the current data or time, and it seems I don't have a suitable tool for that at the moment. Could you please specify what kind of data you're interested in?

# %% [markdown]
# ## Langraph implmentation

# %%
from langchain_core.tools import tool
from services.langraph_client import Langraph_LLM_Client
from models.llm_message import LLMUserMessage
from services.llm_langraph_tools import ALL_TOOLS

# Create LangGraph client
langraph_client = Langraph_LLM_Client(tools=ALL_TOOLS)

# Test it
messages = [
    LLMUserMessage(content="What is 5 * 6? Also tell me the current time.")
]

response = await langraph_client.generate(messages=messages)
print(response)
# Out:
# The result of 5 * 6 is 30. The current time is Wednesday, December 10, 2025 at 05:32:52 PM. Please note that the date and time provided are illustrative and the actual current time may be different.

# %% [markdown]
# ### Test langraph structured output

# %%
from services.langraph_client import Langraph_LLM_Client
from services.llm_langraph_tools import ALL_TOOLS
from models.llm_message import LLMUserMessage, LLMSystemMessage
from pydantic import BaseModel, Field
from typing import List, Optional, Literal

# Define Presentation Schema with Pydantic
class Slide(BaseModel):
    slide_number: int = Field(ge=1, description="Slide number in sequence")
    type: Literal["title", "content", "image", "two_column", "conclusion"] = Field(
        description="Type of slide layout"
    )
    title: str = Field(min_length=1, max_length=100, description="Slide title")
    content: Optional[List[str]] = Field(
        default=None, 
        description="Bullet points or main content (max 7 points)",
        max_length=7
    )
    left_column: Optional[List[str]] = Field(
        default=None,
        description="Content for left column in two-column layout"
    )
    right_column: Optional[List[str]] = Field(
        default=None,
        description="Content for right column in two-column layout"
    )
    image_prompt: Optional[str] = Field(
        default=None,
        description="Detailed prompt for AI image generation"
    )
    speaker_notes: Optional[str] = Field(
        default=None,
        description="Notes for the presenter"
    )

class Presentation(BaseModel):
    title: str = Field(min_length=3, max_length=100, description="Presentation title")
    subtitle: Optional[str] = Field(
        default=None,
        max_length=150,
        description="Presentation subtitle"
    )
    author: Optional[str] = Field(default=None, description="Presenter name")
    target_audience: str = Field(description="Who is this presentation for?")
    estimated_duration_minutes: int = Field(
        ge=5,
        le=120,
        description="Estimated presentation duration in minutes"
    )
    slides: List[Slide] = Field(
        min_length=3,
        max_length=30,
        description="List of slides in the presentation"
    )
    key_takeaways: List[str] = Field(
        min_length=1,
        max_length=5,
        description="Main takeaways from the presentation"
    )

# Create messages
messages = [
    LLMSystemMessage(content="""You are an expert presentation designer. 
    Create engaging, well-structured presentations with clear content.
    
    Guidelines:
    - First slide should be type 'title'
    - Last slide should be type 'conclusion'
    - Keep bullet points concise (5-7 words each)
    - Use 'image' type when visuals would enhance understanding
    - Add speaker notes with additional context
    - Ensure logical flow between slides"""),
    
    LLMUserMessage(content="""Create a professional presentation about 
    "Introduction to Machine Learning for Business Leaders"
    
    Requirements:
    - Target audience: C-level executives with no technical background
    - Duration: 15-20 minutes (around 8-10 slides)
    - Include: 
      * What is ML and why it matters
      * Real-world business applications
      * ROI examples
      * Getting started roadmap
    - Use clear, non-technical language
    - Include at least 1 image slide with a prompt for generating relevant visuals
    """)
]

# Create client
llm_client = Langraph_LLM_Client(tools=ALL_TOOLS)

# Generate structured presentation
result = await llm_client.generate_structured(
    messages=messages,
    response_format=Presentation,
    strict=False  # Allow flexibility for creativity
)

# Display result
print("=" * 60)
print(f"PRESENTATION: {result['title']}")
print(f"Subtitle: {result.get('subtitle', 'N/A')}")
print(f"Target Audience: {result['target_audience']}")
print(f"Duration: {result['estimated_duration_minutes']} minutes")
print(f"Total Slides: {len(result['slides'])}")
print("=" * 60)

for slide in result['slides']:
    print(f"\n[Slide {slide['slide_number']}] - {slide['type'].upper()}")
    print(f"Title: {slide['title']}")
    
    if slide.get('content'):
        print("Content:")
        for bullet in slide['content']:
            print(f"  • {bullet}")
    
    if slide.get('left_column'):
        print("Left Column:")
        for item in slide['left_column']:
            print(f"  • {item}")
    
    if slide.get('right_column'):
        print("Right Column:")
        for item in slide['right_column']:
            print(f"  • {item}")
    
    if slide.get('image_prompt'):
        print(f"Image: {slide['image_prompt']}")
    
    if slide.get('speaker_notes'):
        print(f"Notes: {slide['speaker_notes'][:100]}...")
    
    print("-" * 60)

print("\nKEY TAKEAWAYS:")
for i, takeaway in enumerate(result['key_takeaways'], 1):
    print(f"{i}. {takeaway}")
